# %%
import pandas as pd
from pathlib import Path

# %%
db = Path("/statcast_batter_stats_2023_2025.csv")

# %%
df = pd.read_csv("statcast_batter_stats_2023_2025.csv")

# %%
df
# Out:
#      last_name, first_name  player_id  year  player_age   pa  k_percent  \
# 0          Heineman, Tyler     623168  2025          34   51       19.6
# 1            Hoerner, Nico     663538  2024          27  641       10.3
# 2          Alvarez, Yordan     670541  2024          27  635       15.0
# 3             Altuve, Jose     514888  2024          34  682       17.4
# 4             Thomas, Alek     677950  2024          24  103       16.5
# ...                    ...        ...   ...         ...  ...        ...
# 1733           Ellis, Drew     656403  2023          27   29       24.1
# 1734       Marchán, Rafael     665561  2024          25   56       14.3
# 1735          Rogers, Jake     668670  2025          30   33       27.3
# 1736           Allen, Nick     669397  2025          26  157       21.0
# 1737        Crawford, J.P.     641487  2023          28  638       19.6
#
#       bb_percent  batting_avg  slg_percent  on_base_percent  ...  \
# ...

# %%
data = [
    'last_name, first_name', 'player_id', 'player_age', 'pa', 'k_percent',
    'bb_percent', 'batting_avg', 'slg_percent', 'on_base_percent',
    'on_base_plus_slg', 'woba', 'avg_swing_speed', 'avg_swing_length',
    'exit_velocity_avg', 'barrel_batted_rate', 'hard_hit_percent',
    'avg_best_speed', 'iz_contact_percent', 'swing_percent', 'pull_percent',
    'straightaway_percent', 'opposite_percent', 'sprint_speed'
]

new_df = df[data]
new_df.head(10)
# Out:
#   last_name, first_name  player_id  player_age   pa  k_percent  bb_percent  \
# 0       Heineman, Tyler     623168          34   51       19.6         3.9
# 1         Hoerner, Nico     663538          27  641       10.3         6.9
# 2       Alvarez, Yordan     670541          27  635       15.0        10.9
# 3          Altuve, Jose     514888          34  682       17.4         6.9
# 4          Thomas, Alek     677950          24  103       16.5         6.8
# 5        Garcia, Maikel     672580          24  626       16.5         6.7
# 6        Peralta, David     444482          35  422       17.1         4.7
# 7        Correa, Carlos     621043          28  580       22.6        10.2
# 8          Reyes, Pablo     622569          29  185       11.4         7.6
# 9         Jones, Jahmai     663330          25   11       45.5         9.1
#
#    batting_avg  slg_percent  on_base_percent  on_base_plus_slg  ...  \
# 0        0.396        0.542            0.412             0.954  ...
# ...

# %%
new_drop_df = df.drop_duplicates(subset=["last_name, first_name"])
new_drop_df
# Out:
#      last_name, first_name  player_id  year  player_age   pa  k_percent  \
# 0          Heineman, Tyler     623168  2025          34   51       19.6
# 1            Hoerner, Nico     663538  2024          27  641       10.3
# 2          Alvarez, Yordan     670541  2024          27  635       15.0
# 3             Altuve, Jose     514888  2024          34  682       17.4
# 4             Thomas, Alek     677950  2024          24  103       16.5
# ...                    ...        ...   ...         ...  ...        ...
# 1695       Loperfido, Joey     694388  2024          25  262       36.3
# 1701       Berroa, Steward     672642  2024          25   45       31.1
# 1712       Teodosio, Bryce     669326  2024          25   12       41.7
# 1717      Bemboom, Anthony     621532  2023          33   13       15.4
# 1733           Ellis, Drew     656403  2023          27   29       24.1
#
#       bb_percent  batting_avg  slg_percent  on_base_percent  ...  \
# ...

# %%
new_drop_df.to_csv('unique_players.csv', index=False)
